# %% [markdown]
# #  Code for Alzheimer’s Disease

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Load and preprocess the dataset
# Assuming the images are organized in subdirectories for each class
train_datagen = ImageDataGenerator(rescale=1./255, 
                                   shear_range=0.2, 
                                   zoom_range=0.2, 
                                   horizontal_flip=True)

# Define the path to your dataset
train_directory = 'path_to_your_dataset/train'

train_generator = train_datagen.flow_from_directory(train_directory, 
                                                    target_size=(150, 150), 
                                                    batch_size=32, 
                                                    class_mode='categorical')

# Split the dataset into train and validation
train_images, val_images = train_test_split(train_generator, test_size=0.2)

# CNN Model Architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    
    Flatten(),
    
    Dense(128, activation='relu'),
    Dropout(0.5),
    
    Dense(4, activation='softmax')  # 4 classes: Mild, Moderate, Non-Demented, Very Mild
])

# Compile the model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# Train the model
history = model.fit(train_images, epochs=10, validation_data=val_images)

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Save the trained model
model.save('alzheimer_model.h5')

# %% [markdown]
# #  Code for Data Collection and Model Training

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt

# Define directories for train and validation data
train_directory = 'data/alzheimer/train'
test_directory = 'data/alzheimer/test'

# Data Augmentation and Preprocessing
train_datagen = ImageDataGenerator(rescale=1./255, 
                                   shear_range=0.2, 
                                   zoom_range=0.2, 
                                   horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(train_directory, 
                                                    target_size=(150, 150), 
                                                    batch_size=32, 
                                                    class_mode='categorical')

test_generator = test_datagen.flow_from_directory(test_directory, 
                                                  target_size=(150, 150), 
                                                  batch_size=32, 
                                                  class_mode='categorical')

# CNN Model Architecture
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    
    Flatten(),
    
    Dense(128, activation='relu'),
    Dropout(0.5),
    
    Dense(4, activation='softmax')  # 4 classes: Non-Demented, Mild, Moderate, Very Mild
])

# Compile the model
model.compile(optimizer='adam', 
              loss='categorical_crossentropy', 
              metrics=['accuracy'])

# Train the model
history = model.fit(train_generator, epochs=10, validation_data=test_generator)

# Plot training and validation accuracy
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Model Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Save the trained model
model.save('alzheimers_classification_model.h5')

# %% [markdown]
# # printing the first 4 rows of the dataframe
#
# Alzheimer's disease_data.head()

# %%
import pandas as pd

# Define the dataset
data = {
    "ID": [1, 2, 3, 4],
    "Class": ["Mild", "Moderate", "Early", "Advanced"],
    "MRI Image Feature 1": [0.23, 0.34, 0.21, 0.39],
    "MRI Image Feature 2": [0.56, 0.62, 0.53, 0.59],
    "MRI Image Feature 3": [0.88, 0.81, 0.77, 0.85],
    "MRI Image Feature 4": [0.45, 0.67, 0.44, 0.70],
    "MRI Image Feature 5": [0.91, 0.89, 0.87, 0.90]
}

# Create DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#    ID     Class  MRI Image Feature 1  MRI Image Feature 2  \
# 0   1      Mild                 0.23                 0.56
# 1   2  Moderate                 0.34                 0.62
# 2   3     Early                 0.21                 0.53
# 3   4  Advanced                 0.39                 0.59
#
#    MRI Image Feature 3  MRI Image Feature 4  MRI Image Feature 5
# 0                 0.88                 0.45                 0.91
# 1                 0.81                 0.67                 0.89
# 2                 0.77                 0.44                 0.87
# 3                 0.85                 0.70                 0.90
